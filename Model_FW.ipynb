# %% [markdown]
# ## Imports

# %%
import math
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import networkx as nx 

import folium
import json
import geopandas as gpd
from shapely.geometry import LineString
import json
import heapq
from collections import defaultdict, deque
import queue

import random
import os

# %% [markdown]
# ## Data

# %%
df_links = pd.read_csv("data/IC_NETWORK/df_links.csv") 
df_distances = pd.read_csv("data/distance_matrix.csv") 
df_od = pd.read_csv("data/od_df.csv")

# %%
df_links.start_node.unique()
# Out:
# array(['Zürich HB', 'Winterthur', 'Basel SBB', 'Fribourg/Freiburg',
#        'Thun', 'Lugano Nord', 'Olten', 'Biel/Bienne', 'Lausanne', 'Zug',
#        'Luzern', 'Genève'], dtype=object)

# %%
df_links.head()
# Out:
#   start_node         end_node  distance [m]        IC_lines
# 0  Zürich HB             Chur    116075.402             IC3
# 1  Zürich HB       Winterthur     26787.367       IC5, IC81
# 2  Zürich HB            Baden     22587.175             IC3
# 3  Zürich HB             Bern    120492.589  IC1, IC8, IC81
# 4  Zürich HB  Zürich Oerlikon      5368.417             IC1

# %%
map = df_distances.columns[1:].to_list()

df_od['org'] = df_od['org'].map(lambda x: map[x])
df_od['dest'] = df_od['dest'].map(lambda x: map[x])

df_od.head()
# Out:
#    od_id   org        dest       q
# 0      0  Bern   Basel SBB  3671.0
# 1      1  Bern    Lausanne  1935.0
# 2      2  Bern      Luzern  9477.0
# 3      3  Bern  St. Gallen   924.0
# 4      4  Bern  Winterthur  3344.0

# %% [markdown]
# ### Data manipulation
#
# To correctly model the network with transfers, we decided to model the transfers between lines at a station as seperate edges. By doing this we can have full control over transfer costs, line headways, ...
#
# Each station - line pair is modeled as a seperate node in the network, to change lines at a node there is an additional edge to represent the transfer.

# %% [markdown]
# ### Modelling transfers

# %%
# Function to split multiple train lines and create individual connections
def process_multi_line_connections(df_links):

    """Expand rows with multiple train lines into individual connections"""
    
    rows = []
    
    for _, row in df_links.iterrows():
        # Check if there are multiple lines (comma-separated)
        if ',' in str(row['IC_lines']):
            # Split the lines and create a row for each line
            for line in [l.strip() for l in row['IC_lines'].split(',')]:
                new_row = row.copy()
                new_row['IC_lines'] = line
                rows.append(new_row)
        else:
            # Single line connection
            rows.append(row)

    df_expanded = pd.DataFrame(rows)
    
    return df_expanded

# %%
# Create bidirectional network with individual train lines
def create_bidirectional_network(df_expanded):
    
    # Create reversed connections for bidirectional network
    df_reversed = df_expanded.copy()
    df_reversed['start_node'], df_reversed['end_node'] = df_reversed['end_node'], df_reversed['start_node']
    
    # Combine original and reversed connections
    df_bidirectional = pd.concat([df_expanded, df_reversed], ignore_index=True)
    
    return df_bidirectional

# %%
# Add transfer edges between lines at the same station
def add_transfer_edges(df_bidirectional, transfer_time):
    
    """Add edges representing transfers between different lines at the same station"""
    
    # Get all unique station-line combinations
    station_lines = []
    for _, row in df_bidirectional.iterrows():
        station_lines.append((row['start_node'], row['IC_lines']))
    
    # Remove duplicates
    station_lines = list(set(station_lines))
    
    # Find stations with multiple lines
    stations = {}
    for station, line in station_lines:
        if station not in stations:
            stations[station] = []
        stations[station].append(line)
    
    # Create transfer edges
    transfer_edges = []
    
    for station, lines in stations.items():
        if len(lines) > 1:  # Only stations with multiple lines need transfers
            for i, line1 in enumerate(lines):
                for line2 in lines[i+1:]:
                    # Create bidirectional transfer edges
                    transfer_edges.append({
                        'start_node': station,
                        'end_node': station,
                        'distance [m]': 0,
                        'IC_lines': f"TRANSFER_{line1}_to_{line2}",
                        'transfer_time': transfer_time,
                        'is_transfer': True
                    })
                    transfer_edges.append({
                        'start_node': station,
                        'end_node': station,
                        'distance [m]': 0,
                        'IC_lines': f"TRANSFER_{line2}_to_{line1}",
                        'transfer_time': transfer_time,
                        'is_transfer': True
                    })
    
    # Convert to DataFrame
    transfer_df = pd.DataFrame(transfer_edges)
    
    # Add is_transfer column to original DataFrame
    df_bidirectional['is_transfer'] = False
    
    # Combine regular and transfer edges
    full_network = pd.concat([df_bidirectional, transfer_df], ignore_index=True)

    return full_network

# %%
# Create node-line pairs for modified Dijkstra
def create_node_line_pairs(network_df):
    
    """Create unique identifiers for each (station, line) combination"""
    
    # For regular edges: add source line and destination line
    network_df['source_line'] = network_df['IC_lines']
    
    # For transfer edges: extract source and destination lines
    transfer_mask = network_df['is_transfer']
    network_df.loc[transfer_mask, 'source_line'] = network_df.loc[transfer_mask, 'IC_lines'].apply(
        lambda x: x.split('_')[1]
    )
    network_df.loc[transfer_mask, 'dest_line'] = network_df.loc[transfer_mask, 'IC_lines'].apply(
        lambda x: x.split('_')[3]
    )
    
    # For regular edges: destination line is the same as source line
    network_df.loc[~transfer_mask, 'dest_line'] = network_df.loc[~transfer_mask, 'source_line']
    
    # Create node-line identifiers
    network_df['source_id'] = network_df['start_node'] + "_" + network_df['source_line']
    network_df['dest_id'] = network_df['end_node'] + "_" + network_df['dest_line']
    
    return network_df

# %%
# Calculate travel times on edges
def calculate_travel_times(network_df, speed_kmh=80):
    
    """Convert distances to travel times and add transfer penalties"""
    
    network_df['travel_time'] = np.where(
        network_df['is_transfer'],
        network_df['transfer_time'] + network_df['headway']/2,
        network_df['distance [m]'] / 1000 / speed_kmh * 60  + network_df['headway']/2 # Convert to minutes
    )
    
    return network_df

# %% [markdown]
# ### Setting the headway, speed and capacity of the train lines

# %%
h30_line = ['IC3', 'IC5', 'IC6', 'IC61', 'IC81']
h60_line = ['IC1', 'IC2', 'IC8', 'IC21', 'IC51']

# On average we assume a train to have 500 places
avg_capacity = 500

# We assume a full day of service 6h - 21h 
nb_train30 = 30
nb_train60 = 15

def add_capacity(row):
    if row['source_line'] != row['dest_line']:
        return np.inf
    if row['source_line'] == row['dest_line']and row['source_line'] in h30_line:
        return nb_train30 * avg_capacity
    if row['source_line'] == row['dest_line']and row['source_line'] in h60_line:
        return nb_train60 * avg_capacity
    
def add_headway(row):
    if row['source_line'] != row['dest_line']:
        if row['dest_line'] in h30_line:
            return 30
        else :
            return 60
    if row['source_line'] == row['dest_line']and row['source_line'] in h30_line:
        return 30
    if row['source_line'] == row['dest_line']and row['source_line'] in h60_line:
        return 60

# %%
H = 15 ## Here define the headway ---> we could make it more modulare and define a headway per line if wanted 
T = 5 ## Here define the transfer cost (5 mins to start)
V = 80 ## Here define the train speed 


df_expanded = process_multi_line_connections(df_links)
df_bidirectional = create_bidirectional_network(df_expanded)
full_network = add_transfer_edges(df_bidirectional, transfer_time=T)
full_network_with_names = create_node_line_pairs(full_network)

full_network_with_names['headway'] = full_network_with_names.apply(add_headway, axis=1)


df_network = calculate_travel_times(full_network_with_names, speed_kmh=V)    

df_network['capacity'] = df_network.apply(add_capacity, axis=1)
df_network.head(-10)
# Out:
#      start_node    end_node  distance [m]              IC_lines  is_transfer  \
# 0     Zürich HB        Chur    116075.402                   IC3        False
# 1     Zürich HB  Winterthur     26787.367                   IC5        False
# 2     Zürich HB  Winterthur     26787.367                  IC81        False
# 3     Zürich HB       Baden     22587.175                   IC3        False
# 4     Zürich HB        Bern    120492.589                   IC1        False
# ..          ...         ...           ...                   ...          ...
# 175  Winterthur  Winterthur         0.000  TRANSFER_IC81_to_IC5         True
# 176  Winterthur  Winterthur         0.000   TRANSFER_IC5_to_IC1         True
# 177  Winterthur  Winterthur         0.000   TRANSFER_IC1_to_IC5         True
# 178  Winterthur  Winterthur         0.000  TRANSFER_IC81_to_IC1         True
# 179  Winterthur  Winterthur         0.000  TRANSFER_IC1_to_IC81         True
#
#      transfer_time source_line dest_line        source_id          dest_id  \
# 0              NaN         IC3       IC3    Zürich HB_IC3         Chur_IC3
# 1              NaN         IC5       IC5    Zürich HB_IC5   Winterthur_IC5
# 2              NaN        IC81      IC81   Zürich HB_IC81  Winterthur_IC81
# 3              NaN         IC3       IC3    Zürich HB_IC3        Baden_IC3
# 4              NaN         IC1       IC1    Zürich HB_IC1         Bern_IC1
# ..             ...         ...       ...              ...              ...
# 175            5.0        IC81       IC5  Winterthur_IC81   Winterthur_IC5
# 176            5.0         IC5       IC1   Winterthur_IC5   Winterthur_IC1
# 177            5.0         IC1       IC5   Winterthur_IC1   Winterthur_IC5
# 178            5.0        IC81       IC1  Winterthur_IC81   Winterthur_IC1
# 179            5.0         IC1      IC81   Winterthur_IC1  Winterthur_IC81
#
#      headway  travel_time  capacity
# 0         30   102.056551   15000.0
# 1         30    35.090525   15000.0
# 2         30    35.090525   15000.0
# 3         30    31.940381   15000.0
# 4         60   120.369442    7500.0
# ..       ...          ...       ...
# 175       30    20.000000       inf
# 176       60    35.000000       inf
# 177       30    20.000000       inf
# 178       60    35.000000       inf
# 179       30    20.000000       inf
#
# [180 rows x 13 columns]

# %% [markdown]
# ### Let's now visualize the network

# %%
G = nx.DiGraph()

for _, row in df_network.iterrows():
    G.add_edge(row['source_id'], row['dest_id'], weight=row['travel_time'])

plt.figure(figsize=(10, 7))
pos = nx.spring_layout(G, seed=42) 
nx.draw(G, pos, with_labels=True, node_size=700, node_color='lightblue', arrowsize=6, font_size=6)
plt.title('Railway Network Graph')
plt.show()

# %% [markdown]
# ### All or nothing assignment
#
# Since we have modeled our network with all these seperate nodes and edges to represent transfers, we can easily use the label correction algorithm used for standard traffic assignment
#
# However, to be able to give the algorithm just a city name and not a city_line combo, we had to do a quick manipulation

# %%
def shortest_path_tree(df_node, df_link, t, org): 

    """
    Generate shortest path tree from a given origin node
    using label correction
    
    :param df_node, df_link: network data frames
    :param t: link cost
    :param org: origin node
    
    :return u: node label
    :return p: previous link on shortest path for each node
    """
    
    # define inputs
    n_node = len(df_node)

    r = int(org)

    outflow_link_frst = df_node.frst_out.values
    outflow_link_lst = df_node.lst_out.values

    start_node = df_link.start_node.values
    end_node = df_link.end_node.values


    # initialize
    u = np.inf * np.ones(n_node)
    u[r] = 0
    p = -1 * np.ones(n_node, dtype=int)
    Q = queue.Queue()
    Q.put(r) 

    while Q.qsize() > 0:

        node_i = Q.get()

        link_frst = outflow_link_frst[node_i]
        link_lst = outflow_link_lst[node_i]
        
        for link in range(link_frst, link_lst+1):
            node_j = end_node[link]
            if u[node_j] > u[node_i] + t[link]:
                u[node_j] = u[node_i] + t[link]
                p[node_j] = link  # instead of start node, assigning link here
                if node_j not in Q.queue:
                    Q.put(node_j)

    return u, p

# %%
def label_correction(t, r, n_node, outflow_link_frst, outflow_link_lst, end_node):
    
    """
    Generate shortest path tree from a given origin node using label correction

    :param t: link cost 
    :param r: origin node index
    :param n_node: number of nodes

    :param outflow_link_frst (outflow_link_lst): list of first (last) outflow link indices for each node
    :param end_node: list of end node indices for each link

    :return u: node label
    :return p: previous link on shortest path for each node
    """

    # initialize
    u = np.inf * np.ones(n_node)
    u[r] = 0
    p = -1 * np.ones(n_node, dtype=int)
    Q = queue.Queue()
    Q.put(r) 

    while Q.qsize() > 0 :

        node_i = Q.get() 

        link_frst = outflow_link_frst[node_i]
        link_lst = outflow_link_lst[node_i]
        
        for link in range(link_frst, link_lst + 1):

            node_j = end_node[link]

            if u[node_j] > u[node_i] + t[link] :

                u[node_j] = u[node_i] + t[link]
                p[node_j] = link
                Q.put(node_j)


    return u, p

# %%
def prepare_for_dijkstra(network_df):

    """Prepare network data for Dijkstra algorithm"""
    
    network_df = network_df.sort_values(['source_id', 'dest_id']).reset_index(drop=True)
    network_df['link_index'] = network_df.index

    grouped = network_df.groupby('source_id')['link_index'].agg(['min', 'max']).reset_index()

    node_df = pd.DataFrame({'node_id': grouped['source_id'],'frst_out': grouped['min'],'lst_out': grouped['max']})
    
    node_to_idx = {node: idx for idx, node in enumerate(node_df['node_id'])}
    end_node_indices = np.array([node_to_idx.get(node, -1) for node in network_df['dest_id']])
    

    # Create station to node mapping for flexible querying ---> so we can use just city names
    station_to_nodes = {}
    for node_id in node_df['node_id']:
        if '_' in node_id:
            station = node_id.split('_')[0]
            if station not in station_to_nodes:
                station_to_nodes[station] = []
            station_to_nodes[station].append(node_id)
    
    return node_df, node_to_idx, end_node_indices, network_df, station_to_nodes

# %%
def get_origin_nodes(origin_input, node_to_idx, station_to_nodes):

    """
    Get origin node indices based on input (can be station name or full node ID)
    Returns list of node indices
    """
    
    # Check if it's a full node ID
    if origin_input in node_to_idx:
        return [node_to_idx[origin_input]]
    
    # Check if it's a station name
    if origin_input in station_to_nodes:
        return [node_to_idx[node_id] for node_id in station_to_nodes[origin_input]]
    
    # If neither found, raise error
    raise ValueError(f"Origin '{origin_input}' not found in network")

# %%
node_df, node_to_idx, end_node_indices, network_df_sorted, station_to_nodes = prepare_for_dijkstra(df_network)

n_node = len(node_df)
outflow_link_frst = node_df['frst_out'].values
outflow_link_lst = node_df['lst_out'].values
link_costs = network_df_sorted['travel_time'].values


origin_input = "Lausanne"

origin_indices = get_origin_nodes(origin_input, node_to_idx, station_to_nodes)


# Multiple origin nodes - run algorithm from each and combine results
best_u = np.inf * np.ones(n_node)
best_p = -1 * np.ones(n_node, dtype=int)

for origin_idx in origin_indices:
    u, p = label_correction(link_costs, origin_idx, n_node, outflow_link_frst, outflow_link_lst, end_node_indices)
    
    # Update best paths
    for i in range(n_node):
        if u[i] < best_u[i]:
            best_u[i] = u[i]
            best_p[i] = p[i]

# %%
best_u
# Out:
# array([193.29906675, 291.35912675, 262.6483115 , 248.10605125,
#        228.10605125, 232.6483115 , 232.6483115 , 467.494849  ,
#        432.494849  , 132.66618375, 152.66618375, 152.66618375,
#        167.66618375, 152.66618375, 108.21605775, 143.21605775,
#        361.475297  ,  79.3337625 , 109.6086135 ,  75.1699725 ,
#          0.        ,   0.        , 519.1661455 , 484.1661455 ,
#        549.661096  , 514.661096  , 275.0950835 ,  71.31596775,
#        203.26901375, 168.26901375, 188.26901375, 188.26901375,
#        367.36355225, 332.36355225, 191.11419275, 191.11419275,
#        221.11419275, 191.11419275, 309.50927075, 274.50927075,
#        293.12615075, 326.116019  , 253.0356255 , 274.4187455 ,
#        259.4187455 , 239.4187455 , 274.4187455 , 258.0356255 ,
#        287.06193825])

# %%
best_p
# Out:
# array([100, 161,  95,  15,  68, 105, 110,  32,  91,  71,  35,  36,  37,
#         38,  93,  65, 162,  76,  74,  77,  -1,  -1,  30,  33,  83,  86,
#         96,  80, 102,  67, 103, 104, 117, 139,  46,  52,  57,  63, 140,
#        169, 182, 155,  40, 171, 172,   1, 173,  64, 154])

# %%
unreachable_indices = np.where(best_p == -1)[0]
print("Unreachable nodes:")
for idx in unreachable_indices:
    print(f"Index {idx}: {node_df.iloc[idx]['node_id']}")
# Out:
# Unreachable nodes:
# Index 20: Lausanne_IC1
# Index 21: Lausanne_IC5

# %%
def all_or_nothing_assignment(df_od, node_df, network_df_sorted, node_to_idx, station_to_nodes, t):
    """
    Debug version of all-or-nothing assignment with detailed logging
    """
    
    # Initialize link flows
    n_link = len(network_df_sorted)
    x = np.zeros(n_link)
    
    # Debug counters
    total_demand_processed = 0
    missing_origins = 0
    missing_destinations = 0
    successful_assignments = 0
    
    # Get network parameters
    n_node = len(node_df)
    outflow_link_frst = node_df['frst_out'].values
    outflow_link_lst = node_df['lst_out'].values
    end_node_indices = np.array([node_to_idx.get(node, -1) for node in network_df_sorted['dest_id']])
    
    # Get unique origins from OD matrix
    unique_origins = np.unique(df_od['org'].values)
    print(f"Processing {len(unique_origins)} unique origins")
    print(f"Sample origins: {list(unique_origins[:5])}")
    
    for i, origin_station in enumerate(unique_origins):
        if i % 5 == 0:  # Progress indicator
            print(f"Processing origin {i+1}/{len(unique_origins)}: {origin_station}")
        
        # Get origin node indices
        if origin_station in station_to_nodes:
            origin_indices = [node_to_idx[node_id] for node_id in station_to_nodes[origin_station]]
        elif origin_station in node_to_idx:
            origin_indices = [node_to_idx[origin_station]]
        else:
            print(f"ERROR: Origin {origin_station} not found in network")
            missing_origins += 1
            continue
        
        # Run shortest path from all nodes at this station
        best_u = np.inf * np.ones(n_node)
        best_p = -1 * np.ones(n_node, dtype=int)
        
        for origin_idx in origin_indices:
            u, p = label_correction(t, origin_idx, n_node, outflow_link_frst, outflow_link_lst, end_node_indices)
            
            # Update best paths
            for j in range(n_node):
                if u[j] < best_u[j]:
                    best_u[j] = u[j]
                    best_p[j] = p[j]
        
        # Get OD pairs for this origin
        origin_ods = df_od[df_od['org'] == origin_station]
        
        for _, od_row in origin_ods.iterrows():
            dest_station = od_row['dest']
            demand = od_row['q']
            total_demand_processed += demand
            
            # Get destination node index
            if dest_station in station_to_nodes:
                dest_node_id = station_to_nodes[dest_station][0]
                dest_idx = node_to_idx[dest_node_id]
            elif dest_station in node_to_idx:
                dest_idx = node_to_idx[dest_station]
            else:
                print(f"ERROR: Destination {dest_station} not found in network")
                missing_destinations += 1
                continue
            
            # Check if destination is reachable
            if best_u[dest_idx] == np.inf:
                print(f"ERROR: {dest_station} unreachable from {origin_station}")
                continue
            
            # Trace back shortest path and assign flow
            current_node = dest_idx
            path_length = 0
            max_path_length = n_node
            links_in_path = []
            
            while best_p[current_node] != -1 and path_length < max_path_length:
                link_idx = best_p[current_node]
                links_in_path.append(link_idx)
                x[link_idx] += demand
                
                # Move to previous node
                source_node_id = network_df_sorted.iloc[link_idx]['source_id']
                current_node = node_to_idx[source_node_id]
                path_length += 1
            
            if path_length >= max_path_length:
                print(f"ERROR: Infinite loop for {origin_station} -> {dest_station}")
            else:
                successful_assignments += 1
                
            # Debug first few assignments
            if successful_assignments <= 3:
                print(f"  OD: {origin_station} -> {dest_station}, demand: {demand}, path length: {path_length}")
    
    print(f"\n=== SUMMARY ===")
    print(f"Total demand in OD matrix: {df_od['q'].sum()}")
    print(f"Total demand processed: {total_demand_processed}")
    print(f"Missing origins: {missing_origins}")
    print(f"Missing destinations: {missing_destinations}")
    print(f"Successful assignments: {successful_assignments}")
    print(f"Total assigned flow: {x.sum()}")
    print(f"Links with zero flow: {np.sum(x == 0)}/{len(x)}")
    print(f"Links with positive flow: {np.sum(x > 0)}/{len(x)}")
    
    return x

# Run the debug version
x_debug = all_or_nothing_assignment(df_od, node_df, network_df_sorted, node_to_idx, station_to_nodes, link_costs)
# Out:
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 3
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 9871206.0
# Links with zero flow: 85/190
# Links with positive flow: 105/190

# %%
# total_demand = df_od['q'].sum()
# total_assigned = x.sum()
# print(f"Total demand: {total_demand}")
# print(f"Total assigned: {total_assigned}")

# %%
def link_cost_function(network_df_sorted, x):

    cap = network_df_sorted['capacity'].values

    travel_time = network_df_sorted['travel_time'].values
    crowdness_cost = 0.15*(x/cap)**3

    t = travel_time + crowdness_cost

    return t

# %%
t = link_cost_function(network_df_sorted, x=1)
len(t)
# Out:
# 190

# %%
def objective(x, t):
    t = x*t
    obj = sum(t)
    return obj

# %%
def line_search(network_df_sorted, x, y, max_gap):
    """
    Determine step size by bisection line search

    :param df_link: link data frame
    :param x: current link flows
    :param y: target link flows
    :param max_gap: gap threshold
    :return step: optimal step size
    """

    # initialize 
    lb = 0
    ub = 1
    step = 0.5
    z = x + step * (y - x)
    t = link_cost_function(network_df_sorted, z)
    diff = np.dot(t, y - x)

    # main loop
    while ub - lb > max_gap or diff > 0:
        # update bounds based on boundary value difference
        if diff < 0:
            lb = step
        else:
            ub = step

        step = 0.5 * (lb + ub)
        z = x + step * (y - x)
        t = link_cost_function(network_df_sorted, z)
        diff = np.dot(t, y - x)


    return step

# %%
max_iter = 100
max_gap = 1e-4
max_gap_ls = 1e-2

# %%
def static_assignment_fw(df_od, df_node, network_df_sorted, max_iter, max_gap, max_gap_ls):
    
    """
    Solve static traffic assignment 
    using Frank-Wolfe algorithm

    :param df_od, df_node, df_link: network data frames
    :param max_iter: max number of iterations of main loop
    :param max_gap: gap threshold of main loop
    :param max_gap_ls: gap threshold of line search
    :return x_star: equilibrium link flow
    :return gap: gap over iterations
    :return obj: objective value over iterations
    """

    # initialize link flow 
    n_link = len(network_df_sorted)
    x = np.zeros(n_link)
    t = link_cost_function(network_df_sorted, x)
    x = all_or_nothing_assignment(df_od, df_node, network_df_sorted, node_to_idx, station_to_nodes, t)

    # main loop 
    gap = np.inf * np.ones(max_iter)
    obj = np.inf * np.ones(max_iter)
    i = 0

    for i in range(max_iter):
        # update link travel time
        t = link_cost_function(network_df_sorted, x)

        # solve target flow
        y = all_or_nothing_assignment(df_od, df_node, network_df_sorted, node_to_idx, station_to_nodes, t)

        # derive step size by line search
        step = line_search(network_df_sorted, x, y, max_gap_ls)

        # compute relative gap
        gap[i] = np.dot(t, x-y)/np.dot(t, x)

        # update link flow
        x += step * (y - x)

        # compute objective value
        obj[i] = objective(x, t)

        # check convergence 
        if gap[i] < max_gap:
            break

    # process outputs
    x_star = x
    gap = gap[:i+1]
    obj = obj[:i+1]

    return x_star, gap, obj

# %%
x, gap, obj = static_assignment_fw(df_od, node_df, network_df_sorted, max_iter, max_gap, max_gap_ls)
# Out:
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 3
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 9871206.0
# Links with zero flow: 85/190
# Links with positive flow: 105/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 6
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 13381569.0
# Links with zero flow: 95/190
# Links with positive flow: 95/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 9
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 13742544.0
# Links with zero flow: 63/190
# Links with positive flow: 127/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 3
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 6
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10854047.0
# Links with zero flow: 86/190
# Links with positive flow: 104/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 11969655.0
# Links with zero flow: 83/190
# Links with positive flow: 107/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 11020046.0
# Links with zero flow: 75/190
# Links with positive flow: 115/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 3
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 5
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 11720538.0
# Links with zero flow: 81/190
# Links with positive flow: 109/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 3
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 5
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 11939548.0
# Links with zero flow: 80/190
# Links with positive flow: 110/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 3
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 5
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10937433.0
# Links with zero flow: 76/190
# Links with positive flow: 114/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 9
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 12485670.0
# Links with zero flow: 64/190
# Links with positive flow: 126/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 3
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 11134488.0
# Links with zero flow: 62/190
# Links with positive flow: 128/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 6
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 11194346.0
# Links with zero flow: 71/190
# Links with positive flow: 119/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 6
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10805260.0
# Links with zero flow: 74/190
# Links with positive flow: 116/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10081895.0
# Links with zero flow: 79/190
# Links with positive flow: 111/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10442848.0
# Links with zero flow: 73/190
# Links with positive flow: 117/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 6
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 11218074.0
# Links with zero flow: 66/190
# Links with positive flow: 124/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 9
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10719282.0
# Links with zero flow: 64/190
# Links with positive flow: 126/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10928792.0
# Links with zero flow: 76/190
# Links with positive flow: 114/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 11234468.0
# Links with zero flow: 69/190
# Links with positive flow: 121/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 6
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10173154.0
# Links with zero flow: 69/190
# Links with positive flow: 121/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10031463.0
# Links with zero flow: 68/190
# Links with positive flow: 122/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 9
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 12376243.0
# Links with zero flow: 72/190
# Links with positive flow: 118/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 9
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 12001242.0
# Links with zero flow: 72/190
# Links with positive flow: 118/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 11093252.0
# Links with zero flow: 65/190
# Links with positive flow: 125/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 9890474.0
# Links with zero flow: 64/190
# Links with positive flow: 126/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 9827410.0
# Links with zero flow: 60/190
# Links with positive flow: 130/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10363400.0
# Links with zero flow: 54/190
# Links with positive flow: 136/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10347843.0
# Links with zero flow: 54/190
# Links with positive flow: 136/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 11179369.0
# Links with zero flow: 70/190
# Links with positive flow: 120/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10335642.0
# Links with zero flow: 70/190
# Links with positive flow: 120/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10630934.0
# Links with zero flow: 64/190
# Links with positive flow: 126/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10412366.0
# Links with zero flow: 60/190
# Links with positive flow: 130/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10563851.0
# Links with zero flow: 72/190
# Links with positive flow: 118/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10261315.0
# Links with zero flow: 66/190
# Links with positive flow: 124/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10051998.0
# Links with zero flow: 65/190
# Links with positive flow: 125/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 11254643.0
# Links with zero flow: 65/190
# Links with positive flow: 125/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10575212.0
# Links with zero flow: 61/190
# Links with positive flow: 129/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10293792.0
# Links with zero flow: 62/190
# Links with positive flow: 128/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 11221368.0
# Links with zero flow: 61/190
# Links with positive flow: 129/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10715233.0
# Links with zero flow: 60/190
# Links with positive flow: 130/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10001831.0
# Links with zero flow: 62/190
# Links with positive flow: 128/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 11086868.0
# Links with zero flow: 61/190
# Links with positive flow: 129/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 11194206.0
# Links with zero flow: 61/190
# Links with positive flow: 129/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10027858.0
# Links with zero flow: 62/190
# Links with positive flow: 128/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10110155.0
# Links with zero flow: 61/190
# Links with positive flow: 129/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 11553248.0
# Links with zero flow: 63/190
# Links with positive flow: 127/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10515372.0
# Links with zero flow: 64/190
# Links with positive flow: 126/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10287166.0
# Links with zero flow: 64/190
# Links with positive flow: 126/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10434741.0
# Links with zero flow: 60/190
# Links with positive flow: 130/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10512329.0
# Links with zero flow: 59/190
# Links with positive flow: 131/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10233504.0
# Links with zero flow: 59/190
# Links with positive flow: 131/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10581272.0
# Links with zero flow: 63/190
# Links with positive flow: 127/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10003834.0
# Links with zero flow: 56/190
# Links with positive flow: 134/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10908296.0
# Links with zero flow: 59/190
# Links with positive flow: 131/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10478843.0
# Links with zero flow: 57/190
# Links with positive flow: 133/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10363162.0
# Links with zero flow: 55/190
# Links with positive flow: 135/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10179585.0
# Links with zero flow: 70/190
# Links with positive flow: 120/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10329882.0
# Links with zero flow: 70/190
# Links with positive flow: 120/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 9939005.0
# Links with zero flow: 67/190
# Links with positive flow: 123/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10688146.0
# Links with zero flow: 53/190
# Links with positive flow: 137/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10847226.0
# Links with zero flow: 51/190
# Links with positive flow: 139/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10214845.0
# Links with zero flow: 48/190
# Links with positive flow: 142/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10528142.0
# Links with zero flow: 67/190
# Links with positive flow: 123/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10836994.0
# Links with zero flow: 69/190
# Links with positive flow: 121/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10131492.0
# Links with zero flow: 62/190
# Links with positive flow: 128/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10997658.0
# Links with zero flow: 58/190
# Links with positive flow: 132/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10604265.0
# Links with zero flow: 58/190
# Links with positive flow: 132/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10099447.0
# Links with zero flow: 60/190
# Links with positive flow: 130/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10688461.0
# Links with zero flow: 53/190
# Links with positive flow: 137/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# ...
# Total assigned flow: 10366444.0
# Links with zero flow: 61/190
# Links with positive flow: 129/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10525138.0
# Links with zero flow: 59/190
# Links with positive flow: 131/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10318215.0
# Links with zero flow: 51/190
# Links with positive flow: 139/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10182229.0
# Links with zero flow: 64/190
# Links with positive flow: 126/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10117497.0
# Links with zero flow: 63/190
# Links with positive flow: 127/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10218376.0
# Links with zero flow: 61/190
# Links with positive flow: 129/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10207070.0
# Links with zero flow: 62/190
# Links with positive flow: 128/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10091183.0
# Links with zero flow: 57/190
# Links with positive flow: 133/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 11125581.0
# Links with zero flow: 56/190
# Links with positive flow: 134/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10923660.0
# Links with zero flow: 61/190
# Links with positive flow: 129/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 9866519.0
# Links with zero flow: 55/190
# Links with positive flow: 135/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10103597.0
# Links with zero flow: 60/190
# Links with positive flow: 130/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 9950445.0
# Links with zero flow: 64/190
# Links with positive flow: 126/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10213580.0
# Links with zero flow: 64/190
# Links with positive flow: 126/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10092375.0
# Links with zero flow: 61/190
# Links with positive flow: 129/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10258567.0
# Links with zero flow: 61/190
# Links with positive flow: 129/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10237912.0
# Links with zero flow: 50/190
# Links with positive flow: 140/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 9958326.0
# Links with zero flow: 59/190
# Links with positive flow: 131/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10086622.0
# Links with zero flow: 61/190
# Links with positive flow: 129/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10141806.0
# Links with zero flow: 60/190
# Links with positive flow: 130/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10377870.0
# Links with zero flow: 57/190
# Links with positive flow: 133/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10131740.0
# Links with zero flow: 54/190
# Links with positive flow: 136/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10319685.0
# Links with zero flow: 62/190
# Links with positive flow: 128/190
# Processing 21 unique origins
# Sample origins: ['Aarau', 'Baden', 'Basel SBB', 'Bellinzona', 'Bern']
# Processing origin 1/21: Aarau
#   OD: Aarau -> Bern, demand: 2758.0, path length: 4
#   OD: Aarau -> Basel SBB, demand: 11851.0, path length: 4
#   OD: Aarau -> Lausanne, demand: 6738.0, path length: 5
# Processing origin 6/21: Biel/Bienne
# Processing origin 11/21: Lausanne
# Processing origin 16/21: Olten
# Processing origin 21/21: Zürich Oerlikon
#
# === SUMMARY ===
# Total demand in OD matrix: 2338598.0
# Total demand processed: 2338598.0
# Missing origins: 0
# Missing destinations: 0
# Successful assignments: 420
# Total assigned flow: 10599021.0
# Links with zero flow: 62/190
# Links with positive flow: 128/190

# %%
plt.figure()
plt.plot(obj)

# %%
x
# Out:
# array([1.40834517e+05, 1.19391340e+05, 1.28308955e+05, 1.26828470e+05,
#        2.66531949e+02, 3.31539679e+01, 0.00000000e+00, 0.00000000e+00,
#        3.92634854e+04, 1.36397812e+05, 6.89613009e+04, 4.04374015e+04,
#        8.79492119e+03, 1.01153318e+04, 3.27493857e+04, 4.24926726e+04,
#        3.10546378e+03, 2.49265508e+03, 8.71712943e+04, 2.73964057e+04,
#        1.16840207e+04, 6.86891825e+03, 0.00000000e+00, 3.64169191e+04,
#        2.36129998e+04, 1.47043290e+04, 6.74951798e+03, 0.00000000e+00,
#        3.62535658e+04, 2.86877828e+04, 6.00799840e+04, 3.23096568e+05,
#        1.55527463e+05, 4.92990160e+04, 1.30800523e+05, 1.93828647e+04,
#        1.56065155e+04, 1.00951564e+04, 2.41377305e+04, 1.25302892e+05,
#        6.03515019e+04, 2.48832757e+04, 0.00000000e+00, 7.29241805e+03,
#        2.93830981e+04, 7.73339416e+04, 3.84375283e+04, 3.87551541e+04,
#        0.00000000e+00, 7.71438307e+03, 4.47233744e+04, 7.36330016e+04,
#        1.41893622e+03, 2.74730348e+04, 9.16981424e+03, 9.51660743e+03,
#        0.00000000e+00, 0.00000000e+00, 4.71732584e+04, 3.82134397e+04,
#        3.35031399e+04, 2.42374174e+04, 0.00000000e+00, 1.59075355e+04,
#        1.16901754e+05, 3.14747702e+04, 1.88561108e+05, 1.82623671e+05,
#        8.08401772e+04, 8.71712943e+04, 3.41010000e+04, 1.13728366e+05,
#        8.78391756e+04, 3.14990000e+04, 4.59270000e+04, 9.49370000e+04,
#        7.52356501e+04, 1.22892000e+05, 5.78848440e+04, 1.50728524e+05,
#        1.32348050e+05, 5.80074778e+04, 0.00000000e+00, 3.46756201e+04,
#        4.94565222e+04, 1.93577564e+04, 2.99423799e+04, 3.44840592e+04,
#        0.00000000e+00, 3.51149408e+04, 2.99423799e+04, 1.72372339e+05,
#        4.08935432e+05, 1.53398634e+05, 1.50728524e+05, 4.98017528e+04,
#        3.05115247e+05, 1.75797024e+05, 7.98890874e+04, 9.10052132e+04,
#        1.49529386e+05, 2.00167028e+05, 1.52365433e+05, 1.97930527e+04,
#        1.33032813e+04, 4.59493446e+04, 8.71564233e+04, 6.86068764e+04,
#        1.50125935e+04, 7.56063245e+01, 4.50668468e+04, 9.08145033e+04,
#        6.58288832e+04, 1.68411660e+04, 1.70688495e+02, 0.00000000e+00,
#        3.86400000e+03, 4.22666887e+04, 3.65360000e+04, 1.72667462e+04,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.60703098e+04,
#        1.41893622e+03, 0.00000000e+00, 0.00000000e+00, 8.55782199e+03,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.70081220e+04,
#        1.59075355e+04, 0.00000000e+00, 0.00000000e+00, 1.05573113e+04,
#        4.16819939e+03, 6.14994013e+03, 4.46327764e+03, 4.22666887e+04,
#        6.76439780e+04, 2.60294407e+03, 9.03942052e+04, 1.11955301e+05,
#        1.64547463e+02, 9.09089343e+04, 2.35369753e+05, 3.30182678e+05,
#        5.59150844e+04, 5.09600720e+04, 1.85545106e+04, 6.09302523e+03,
#        3.33732012e+03, 3.76971963e+03, 5.64020327e+04, 2.70423863e+05,
#        4.49400414e+04, 1.02740004e+05, 9.73643804e+04, 3.34220732e+04,
#        5.17161796e+04, 1.33149614e+05, 6.16840000e+04, 1.21747315e+04,
#        8.07538526e+04, 2.77179331e+04, 6.98900120e+03, 1.44527046e+04,
#        1.21124470e+05, 1.09746119e+05, 8.77313670e+03, 8.02559033e+04,
#        2.38831472e+04, 2.04375545e+03, 1.03747623e+03, 4.61594565e+04,
#        3.84456623e+03, 2.56401717e+04, 1.27715818e+04, 4.39750634e+03,
#        5.19432383e+02, 1.10337515e+05, 1.12119848e+05, 4.11892644e+03,
#        3.28138631e+04, 1.80431229e+04, 1.50561821e+03, 3.67306489e+02,
#        1.89254498e+04, 6.08288605e+04])

# %%
zero_indices = np.where(x == 0)[0]  # [0] perché np.where restituisce una tupla
print("Indici degli zeri:", zero_indices)
zero_flow_link = network_df_sorted.loc[zero_indices]
# Out:
# Indici degli zeri: [  6   7  22  27  42  48  56  57  62  82  88 115 120 121 122 125 126 128
#  129 130 133 134]

# %%
zero_flow_link
# Out:
#       start_node     end_node  distance [m]               IC_lines  \
# 6      Basel SBB    Basel SBB         0.000   TRANSFER_IC21_to_IC6
# 7      Basel SBB    Basel SBB         0.000  TRANSFER_IC21_to_IC61
# 22     Basel SBB    Basel SBB         0.000   TRANSFER_IC6_to_IC61
# 27     Basel SBB    Basel SBB         0.000   TRANSFER_IC61_to_IC6
# 42          Bern         Bern         0.000   TRANSFER_IC6_to_IC61
# 48          Bern         Bern         0.000   TRANSFER_IC61_to_IC6
# 56          Bern         Bern         0.000   TRANSFER_IC8_to_IC81
# 57          Bern         Thun     31264.012                    IC8
# 62          Bern         Bern         0.000   TRANSFER_IC81_to_IC8
# 82   Lugano Nord  Lugano Nord         0.000   TRANSFER_IC2_to_IC21
# 88        Lugano       Lugano         0.000   TRANSFER_IC2_to_IC21
# 115   St. Gallen   St. Gallen         0.000    TRANSFER_IC1_to_IC5
# 120         Thun         Thun         0.000   TRANSFER_IC6_to_IC61
# 121         Thun         Thun         0.000    TRANSFER_IC6_to_IC8
# 122         Thun         Thun         0.000   TRANSFER_IC6_to_IC81
# 125         Thun         Thun         0.000   TRANSFER_IC61_to_IC8
# 126         Thun         Thun         0.000  TRANSFER_IC61_to_IC81
# 128         Thun         Thun         0.000    TRANSFER_IC8_to_IC6
# 129         Thun         Thun         0.000   TRANSFER_IC8_to_IC61
# 130         Thun         Thun         0.000   TRANSFER_IC8_to_IC81
# 133         Thun         Thun         0.000  TRANSFER_IC81_to_IC61
# 134         Thun         Thun         0.000   TRANSFER_IC81_to_IC8
#
#      is_transfer  transfer_time source_line dest_line        source_id  \
# 6           True            5.0        IC21       IC6   Basel SBB_IC21
# 7           True            5.0        IC21      IC61   Basel SBB_IC21
# 22          True            5.0         IC6      IC61    Basel SBB_IC6
# 27          True            5.0        IC61       IC6   Basel SBB_IC61
# 42          True            5.0         IC6      IC61         Bern_IC6
# 48          True            5.0        IC61       IC6        Bern_IC61
# 56          True            5.0         IC8      IC81         Bern_IC8
# 57         False            NaN         IC8       IC8         Bern_IC8
# 62          True            5.0        IC81       IC8        Bern_IC81
# 82          True            5.0         IC2      IC21  Lugano Nord_IC2
# 88          True            5.0         IC2      IC21       Lugano_IC2
# 115         True            5.0         IC1       IC5   St. Gallen_IC1
# 120         True            5.0         IC6      IC61         Thun_IC6
# 121         True            5.0         IC6       IC8         Thun_IC6
# 122         True            5.0         IC6      IC81         Thun_IC6
# 125         True            5.0        IC61       IC8        Thun_IC61
# 126         True            5.0        IC61      IC81        Thun_IC61
# 128         True            5.0         IC8       IC6         Thun_IC8
# 129         True            5.0         IC8      IC61         Thun_IC8
# 130         True            5.0         IC8      IC81         Thun_IC8
# 133         True            5.0        IC81      IC61        Thun_IC81
# 134         True            5.0        IC81       IC8        Thun_IC81
#
#               dest_id  headway  travel_time  capacity  link_index
# 6       Basel SBB_IC6       30    20.000000       inf           6
# 7      Basel SBB_IC61       30    20.000000       inf           7
# 22     Basel SBB_IC61       30    20.000000       inf          22
# 27      Basel SBB_IC6       30    20.000000       inf          27
# 42          Bern_IC61       30    20.000000       inf          42
# 48           Bern_IC6       30    20.000000       inf          48
# 56          Bern_IC81       30    20.000000       inf          56
# 57           Thun_IC8       60    53.448009    7500.0          57
# 62           Bern_IC8       60    35.000000       inf          62
# 82   Lugano Nord_IC21       60    35.000000       inf          82
# 88        Lugano_IC21       60    35.000000       inf          88
# 115    St. Gallen_IC5       30    20.000000       inf         115
# 120         Thun_IC61       30    20.000000       inf         120
# 121          Thun_IC8       60    35.000000       inf         121
# 122         Thun_IC81       30    20.000000       inf         122
# 125          Thun_IC8       60    35.000000       inf         125
# 126         Thun_IC81       30    20.000000       inf         126
# 128          Thun_IC6       30    20.000000       inf         128
# 129         Thun_IC61       30    20.000000       inf         129
# 130         Thun_IC81       30    20.000000       inf         130
# 133         Thun_IC61       30    20.000000       inf         133
# 134          Thun_IC8       60    35.000000       inf         134

# %%
final_cost = link_cost_function(network_df_sorted, x)
final_cost
# Out:
# array([1.49179505e+02, 1.21756968e+02, 1.71594082e+02, 1.22611244e+02,
#        2.00000000e+01, 3.50000000e+01, 2.00000000e+01, 2.00000000e+01,
#        8.09008711e+01, 1.90492747e+02, 3.50000000e+01, 3.50000000e+01,
#        2.00000000e+01, 2.00000000e+01, 3.50000000e+01, 2.00000000e+01,
#        2.00000000e+01, 2.00000000e+01, 3.20410080e+02, 3.50000000e+01,
#        2.00000000e+01, 3.50000000e+01, 2.00000000e+01, 4.65257789e+01,
#        3.50000000e+01, 2.00000000e+01, 3.50000000e+01, 2.00000000e+01,
#        4.64970233e+01, 3.50000000e+01, 1.28778845e+02, 1.21676985e+04,
#        3.50000000e+01, 9.42725348e+01, 9.53075129e+02, 2.00000000e+01,
#        2.00000000e+01, 3.50000000e+01, 2.00000000e+01, 7.52837307e+02,
#        1.98527132e+02, 3.50000000e+01, 2.00000000e+01, 3.50000000e+01,
#        2.00000000e+01, 8.47752041e+01, 4.09719770e+01, 3.50000000e+01,
#        2.00000000e+01, 3.50000000e+01, 2.00000000e+01, 8.19630345e+01,
#        3.84481360e+01, 3.50000000e+01, 2.00000000e+01, 2.00000000e+01,
#        2.00000000e+01, 5.34480090e+01, 1.57694036e+02, 3.50000000e+01,
#        2.00000000e+01, 2.00000000e+01, 3.50000000e+01, 3.86269155e+01,
#        1.76373073e+02, 3.50000000e+01, 3.34870986e+02, 3.30753223e+02,
#        2.72730495e+02, 2.00000000e+01, 1.03819010e+02, 5.76347094e+02,
#        3.20308892e+02, 4.55507826e+01, 6.88824920e+01, 3.79408339e+02,
#        2.30752110e+02, 7.35070242e+02, 2.00000000e+01, 3.50000000e+01,
#        1.74347491e+02, 1.21071288e+02, 3.50000000e+01, 4.53194548e+01,
#        9.46821628e+01, 3.50000000e+01, 4.00397413e+01, 4.50751215e+01,
#        3.50000000e+01, 4.58900780e+01, 3.50000000e+01, 1.97840080e+03,
#        2.43866815e+04, 1.97328750e+02, 2.23512173e+02, 1.03297176e+02,
#        1.01713105e+04, 2.00000000e+01, 2.00000000e+01, 2.00000000e+01,
#        1.73622637e+02, 4.16500071e+02, 3.50000000e+01, 2.00000000e+01,
#        2.00000000e+01, 4.86910664e+01, 9.36446564e+01, 3.50000000e+01,
#        2.00000000e+01, 2.00000000e+01, 4.84473732e+01, 9.75073586e+01,
#        3.50000000e+01, 2.00000000e+01, 2.00000000e+01, 2.00000000e+01,
#        7.28747940e+01, 3.50000000e+01, 6.00218882e+01, 3.86768053e+01,
#        2.00000000e+01, 3.50000000e+01, 2.00000000e+01, 3.86324639e+01,
#        2.00000000e+01, 3.50000000e+01, 2.00000000e+01, 5.36708511e+01,
#        2.00000000e+01, 2.00000000e+01, 2.00000000e+01, 3.86666777e+01,
#        2.00000000e+01, 2.00000000e+01, 3.50000000e+01, 7.32726582e+01,
#        2.00000000e+01, 2.00000000e+01, 4.60958258e+01, 6.12102058e+01,
#        3.50000000e+01, 2.00000000e+01, 6.79181344e+01, 3.50000000e+01,
#        2.00000000e+01, 6.84821216e+01, 4.81151340e+03, 1.28505289e+04,
#        1.82527068e+02, 3.50000000e+01, 2.00000000e+01, 2.00000000e+01,
#        3.50000000e+01, 2.00000000e+01, 9.78220611e+01, 7.08310860e+03,
#        3.50000000e+01, 2.00000000e+01, 2.00000000e+01, 3.50000000e+01,
#        2.00000000e+01, 1.36855291e+02, 1.12487771e+02, 3.50000000e+01,
#        3.50000000e+01, 2.00000000e+01, 3.50000000e+01, 2.00000000e+01,
#        1.25098956e+02, 9.38374311e+01, 3.50000000e+01, 3.50000000e+01,
#        2.00000000e+01, 3.50000000e+01, 2.00000000e+01, 1.55338950e+02,
#        3.50000000e+01, 3.50000000e+01, 2.00000000e+01, 2.00000000e+01,
#        2.00000000e+01, 1.65071194e+02, 9.77324342e+01, 3.50000000e+01,
#        3.50000000e+01, 2.00000000e+01, 2.00000000e+01, 3.50000000e+01,
#        4.84743738e+01, 1.14053308e+02])
